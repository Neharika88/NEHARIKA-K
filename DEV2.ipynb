# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("neha.csv")
df.head(50)
# Out:
#       data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0   05-01-2014  2014      5       14492     RDU       36      11032    CUN
# 1   06-01-2007  2007      6       13204     MCO       33      16085    YHZ
# 2   12-01-2005  2005     12       11433     DTW       43      10411    AUA
# 3   04-01-2003  2003      4       13487     MSP       63      16304    ZIH
# 4   12-01-2005  2005     12       12016     GUM        5      11138    CRK
# 5   03-01-2007  2007      3       14843     SJU        3      15084    SXM
# 6   03-01-2001  2001      3       14986     SRQ       33      13252    MEX
# 7   04-01-2007  2007      4       14027     PBI       33      11760    FRA
# 8   09-01-2005  2005      9       10559     BFI       93      15999    YAZ
# 9   08-01-2004  2004      8       10821     BWI       35      10150    ACC
# 10  06-01-2008  2008      6       13303     MIA       33      15627    VRA
# 11  03-01-2003  2003      3       13296     MHT       14      10411    AUA
# 12  06-01-2004  2004      6       13176     MAZ        3      13068    LRM
# 13  03-01-2004  2004      3       11193     CVG       52      11731    FPO
# 14  02-01-2004  2004      2       12889     LAS       85      16042    YEG
# 15  11-01-2010  2010     11       11764     FRG       22      16149    YOW
# 16  11-01-2009  2009     11       13796     OAK       91      16304    ZIH
# 17  11-01-2003  2003     11       12892     LAX       91      14228    PPT
# 18  07-01-2001  2001      7       13303     MIA       33      14012    PAP
# 19  01-01-2002  2002      1       10693     BNA       54      12909    LBX
# 20  07-01-2006  2006      7       14100     PHL       23      16271    YYZ
# 21  05-01-2002  2002      5       11298     DFW       74      16229    YVR
# 22  01-01-2001  2001      1       13495     MSY       72      11032    CUN
# 23  11-01-2006  2006     11       11292     DEN       82      11032    CUN
# 24  02-01-2005  2005      2       13830     OGG        2      16257    YYC
# 25  03-01-2008  2008      3       12223     HTS       39      16271    YYZ
# 26  02-01-2002  2002      2       13487     MSP       63      14207    POP
# 27  01-01-2001  2001      1       14843     SJU        3      14293    PUJ
# 28  02-01-2002  2002      2       13204     MCO       33      16271    YYZ
# 29  06-01-2002  2002      6       13495     MSY       72      10148    ACA
# 30  07-01-2002  2002      7       10257     ALB       22      10521    BDA
# 31  10-01-2004  2004     10       11423     DSM       61      16178    YQX
# 32  08-01-2001  2001      8       11423     DSM       61      16042    YEG
# 33  03-01-2007  2007      3       12478     JFK       22      14849    SKB
# 34  06-01-2006  2006      6       11433     DTW       43      11032    CUN
# 35  11-01-2009  2009     11       12339     IND       42      16271    YYZ
# 36  05-01-2001  2001      5       12016     GUM        5      11793    FUK
# 37  02-01-2004  2004      2       15016     STL       64      13180    MBJ
# 38  02-01-2001  2001      2       11292     DEN       82      13594    MZT
# 39  05-01-2004  2004      5       13176     MAZ        3      14739    SDQ
# 40  11-01-2010  2010     11       10397     ATL       34      16271    YYZ
# 41  04-01-2009  2009      4       12266     IAH       74      10911    CCS
# 42  01-01-2003  2003      1       13930     ORD       41      13068    LRM
# 43  03-01-2009  2009      3       12187     HOP       52      16178    YQX
# 44  12-01-2002  2002     12       11433     DTW       43      13180    MBJ
# 45  06-01-2005  2005      6       14027     PBI       33      13169    MAR
# 46  09-01-2006  2006      9       11750     FQQ        1      16254    YXY
# 47  05-01-2010  2010      5       11057     CLT       36      13605    NAS
# 48  08-01-2006  2006      8       10917     CDB        1      13483    MSJ
# 49  03-01-2004  2004      3       15016     STL       64      14312    PVR
#
#     fg_wac  airlineid carrier  carriergroup        type  Scheduled  Charter  \
# 0      148      19534      AM             0  Passengers          0      315
# 1      951      20364      C6             0  Passengers          0      683
# 2      277      20344      RD             1  Passengers          0     1010
# 3      148      20204      MG             1  Passengers          0      508
# 4      766      20312      TZ             1  Passengers          0       76
# 5      259      20421     SLQ             1  Passengers          0       35
# 6      148      19704      CO             1  Passengers          0      248
# 7      429      21186     0BQ             0  Passengers          0        2
# 8      906      20345     RGQ             0  Passengers          0        8
# 9      529      20095      WO             1  Passengers          0      624
# 10     219      20401      3M             1  Passengers          0       29
# 11     277      20147      T9             1  Passengers          0      119
# 12     224      20414      OW             1  Passengers          0       49
# 13     204      20203     FCQ             1  Passengers          0     1464
# 14     916      20065     SEQ             0  Passengers          0     1877
# 15     936      20402      GL             1  Passengers          0       41
# 16     148      19930      AS             1  Passengers          0      703
# 17     823      20377      X9             1  Passengers          0     2304
# 18     238      20203     FCQ             1  Passengers          0      289
# 19     766      20305     PCQ             1  Passengers          0       50
# 20     936      20313      W8             0  Passengers          0       49
# 21     906      20204      MG             1  Passengers          0      226
# 22     148      19917      5X             1  Passengers          0       90
# 23     148      20204      MG             1  Passengers          0     2642
# 24     916      20065     SEQ             0  Passengers          0     2955
# 25     936      20293      ZX             0  Passengers          0        5
# 26     224      20344     RYQ             1  Passengers          0      654
# 27     224      20344     RYQ             1  Passengers          0      483
# 28     936      20065     SEQ             0  Passengers          0      693
# 29     148      20402     MMQ             1  Passengers          0      172
# 30     207      19790      DL             1  Passengers          0      468
# 31     961      20312      TZ             1  Passengers          0      233
# 32     916      20402     MMQ             1  Passengers          0      133
# 33     275      20207      XP             1  Passengers          0      152
# 34     148      20204      MG             1  Passengers          0     2336
# 35     936      19386      NW             1  Passengers          0       40
# 36     736      19548      JL             0  Passengers          0     2026
# 37     243      20204      MG             1  Passengers          0     2332
# 38     148      20204      MG             1  Passengers          0     2878
# 39     224      20414      OW             1  Passengers          0       46
# 40     936      19790      DL             1  Passengers          0       36
# 41     388      20095      WO             1  Passengers          0      242
# 42     224      20423     USQ             1  Passengers          0      130
# 43     961      20344      RD             1  Passengers          0      228
# 44     243      20375     TZQ             0  Passengers          0      147
# 45     388      20203     FCQ             1  Passengers          0       78
# 46     911      19976      4N             0  Passengers          0       14
# 47     204      20368      G4             1  Passengers          0      150
# 48     736      20402      GL             1  Passengers          0       93
# 49     148      20368      G4             1  Passengers          0     1240
#
#      Total
# 0    315.0
# 1    683.0
# 2   1010.0
# 3    508.0
# 4     76.0
# 5     35.0
# 6    248.0
# 7      2.0
# 8      8.0
# 9    624.0
# 10    29.0
# 11   119.0
# 12    49.0
# 13  1464.0
# 14  1877.0
# 15    41.0
# 16   703.0
# 17  2304.0
# 18   289.0
# 19    50.0
# 20    49.0
# 21   226.0
# 22    90.0
# 23  2642.0
# 24  2955.0
# 25     5.0
# 26   654.0
# 27   483.0
# 28   693.0
# 29   172.0
# 30   468.0
# 31   233.0
# 32   133.0
# 33   152.0
# 34  2336.0
# 35    40.0
# 36  2026.0
# 37  2332.0
# 38  2878.0
# 39    46.0
# 40    36.0
# 41   242.0
# 42   130.0
# 43   228.0
# 44   147.0
# 45    78.0
# 46    14.0
# 47   150.0
# 48    93.0
# 49  1240.0

# %%
df.describe()
# Out:
#                Year         Month    usg_apt_id       usg_wac     fg_apt_id  \
# count  53728.000000  53728.000000  53728.000000  53728.000000  53728.000000
# mean    2006.251396      6.186272  12951.954809     42.564380  13676.850432
# std        4.674359      3.505447   3991.357869     25.616868   1974.036088
# min     1990.000000      1.000000  10135.000000      1.000000  10125.000000
# 25%     2003.000000      3.000000  11433.000000     22.000000  11928.000000
# 50%     2006.000000      6.000000  12892.000000     33.000000  13618.000000
# 75%     2010.000000      9.000000  14027.000000     64.000000  15999.000000
# max     2015.000000     12.000000  99999.000000     93.000000  16575.000000
#
#              fg_wac     airlineid  carriergroup  Scheduled       Charter  \
# count  53728.000000  53728.000000  53728.000000    53728.0  53728.000000
# mean     443.958644  20333.886409      0.638941        0.0    939.069275
# std      308.351525    475.367292      0.480312        0.0   1995.239573
# min      106.000000  19386.000000      0.000000        0.0      1.000000
# 25%      148.000000  20147.000000      0.000000        0.0     44.000000
# 50%      280.000000  20344.000000      1.000000        0.0    201.000000
# 75%      736.000000  20415.000000      1.000000        0.0   1000.000000
# max      975.000000  21656.000000      1.000000        0.0  42932.000000
#
#               Total
# count  53727.000000
# mean     939.082398
# std     1995.255822
# min        1.000000
# 25%       44.000000
# 50%      201.000000
# 75%     1000.000000
# max    42932.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53728 entries, 0 to 53727
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   data_dte      53728 non-null  object
#  1   Year          53728 non-null  int64
#  2   Month         53728 non-null  int64
#  3   usg_apt_id    53728 non-null  int64
#  4   usg_apt       53728 non-null  object
#  5   usg_wac       53728 non-null  int64
#  6   fg_apt_id     53728 non-null  int64
#  7   fg_apt        53728 non-null  object
#  8   fg_wac        53728 non-null  int64
#  9   airlineid     53728 non-null  int64
#  10  carrier       52963 non-null  object
#  11  carriergroup  53728 non-null  int64
#  12  type          53728 non-null  object
#  13  Scheduled     53728 non-null  int64
#  14  Charter       53728 non-null  int64
#  15  Total         53727 non-null  float64
# dtypes: float64(1), int64(10), object(5)
# memory usage: 6.6+ MB

# %%
df.shape
# Out:
# (53728, 16)

# %%
df.nunique()
# Out:
# data_dte         280
# Year              25
# Month             12
# usg_apt_id       617
# usg_apt          619
# usg_wac           54
# fg_apt_id        855
# fg_apt           855
# fg_wac           168
# airlineid        287
# carrier          309
# carriergroup       2
# type               1
# Scheduled          1
# Charter         5950
# Total           5950
# dtype: int64

# %%
x=df.Year

# %%
y=df.Total

# %%
plt.plot(y,x, color='yellow')
plt.grid(axis = 'x')

# %%
plt.plot(x,y ,'o')

# %%
plt.plot(y, marker = '*', ms=10, mec='r')

# %%
plt.plot(x,y, 'o:r')

# %%
plt.hist(df["Total"])
# Out:
# (array([5.1194e+04, 1.8760e+03, 4.0600e+02, 1.3400e+02, 6.4000e+01,
#         2.9000e+01, 1.0000e+01, 8.0000e+00, 4.0000e+00, 2.0000e+00]),
#  array([1.00000e+00, 4.29410e+03, 8.58720e+03, 1.28803e+04, 1.71734e+04,
#         2.14665e+04, 2.57596e+04, 3.00527e+04, 3.43458e+04, 3.86389e+04,
#         4.29320e+04]),
#  <a list of 10 Patch objects>)

# %%
plt.scatter(x,y)

# %%
plt.stem(x,y)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """Entry point for launching an IPython kernel.
# <StemContainer object of 3 artists>

# %%
plt.polar(x,y)

# %%
plt.fill_between(x,y)

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 53728 artists>

# %%
df.plot.area()

# %%
z=df.fg_wac
plt.pie(z)
plt.show()

# %%
sns.heatmap(df.corr())
