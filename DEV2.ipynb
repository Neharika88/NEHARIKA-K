# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("neha.csv")
df.head(50)
# Out:
#       data_dte    Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0   05-01-2014  2014.0    5.0     14492.0     RDU     36.0    11032.0    CUN
# 1   06-01-2007  2007.0    6.0     13204.0     MCO     33.0    16085.0    YHZ
# 2   12-01-2005  2005.0   12.0     11433.0     DTW     43.0    10411.0    AUA
# 3   04-01-2003  2003.0    4.0     13487.0     MSP     63.0    16304.0    ZIH
# 4   12-01-2005  2005.0   12.0     12016.0     GUM      5.0    11138.0    CRK
# 5   03-01-2007  2007.0    3.0     14843.0     SJU      3.0    15084.0    SXM
# 6   03-01-2001  2001.0    3.0     14986.0     SRQ     33.0    13252.0    MEX
# 7   04-01-2007  2007.0    4.0     14027.0     PBI     33.0    11760.0    FRA
# 8   09-01-2005  2005.0    9.0     10559.0     BFI     93.0    15999.0    YAZ
# 9   08-01-2004  2004.0    8.0     10821.0     BWI     35.0    10150.0    ACC
# 10  06-01-2008  2008.0    6.0     13303.0     MIA     33.0    15627.0    VRA
# ...

# %%
df.describe()
# Out:
#                Year         Month    usg_apt_id       usg_wac     fg_apt_id  \
# count  80211.000000  80211.000000  80211.000000  80211.000000  80211.000000
# mean    2002.415217      6.141813  12854.141065     42.397302  13562.494820
# std        6.856757      3.504644   3364.253576     25.505560   2016.649757
# min     1990.000000      1.000000  10135.000000      1.000000  10125.000000
# 25%     1996.000000      3.000000  11433.000000     22.000000  11731.000000
# 50%     2003.000000      6.000000  12892.000000     33.000000  13605.000000
# 75%     2008.000000      9.000000  13930.000000     64.000000  15584.000000
# max     2015.000000     12.000000  99999.000000     93.000000  16575.000000
#
#              fg_wac     airlineid  carriergroup  Scheduled       Charter  \
# count  80211.000000  80211.000000   80211.00000    80211.0  80211.000000
# mean     432.749959  20242.113638       0.62656        0.0   1057.485968
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80212 entries, 0 to 80211
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   data_dte      80212 non-null  object
#  1   Year          80211 non-null  float64
#  2   Month         80211 non-null  float64
#  3   usg_apt_id    80211 non-null  float64
#  4   usg_apt       80211 non-null  object
#  5   usg_wac       80211 non-null  float64
#  6   fg_apt_id     80211 non-null  float64
#  7   fg_apt        80211 non-null  object
#  8   fg_wac        80211 non-null  float64
#  9   airlineid     80211 non-null  float64
#  10  carrier       79445 non-null  object
#  11  carriergroup  80211 non-null  float64
#  12  type          80211 non-null  object
#  13  Scheduled     80211 non-null  float64
#  14  Charter       80211 non-null  float64
#  15  Total         80211 non-null  float64
# dtypes: float64(11), object(5)
# memory usage: 9.8+ MB

# %%
df.shape
# Out:
# (80212, 16)

# %%
df.nunique()
# Out:
# data_dte         281
# Year              25
# Month             12
# usg_apt_id       651
# usg_apt          655
# usg_wac           54
# fg_apt_id        918
# fg_apt           918
# fg_wac           175
# airlineid        320
# carrier          343
# carriergroup       2
# type               1
# Scheduled          1
# Charter         7153
# Total           7153
# dtype: int64

# %%
x=df.Year

# %%
y=df.Total

# %%
plt.plot(y,x)
plt.grid(axis = 'x')

# %%
plt.plot(x,y ,'o')

# %%
plt.plot(x,y, 'o:r')

# %%
plt.hist(df["Total"],bins=10)
# Out:
# (array([7.618e+04, 2.963e+03, 7.170e+02, 2.060e+02, 8.300e+01, 3.700e+01,
#         1.100e+01, 8.000e+00, 4.000e+00, 2.000e+00]),
#  array([1.00000e+00, 4.29410e+03, 8.58720e+03, 1.28803e+04, 1.71734e+04,
#         2.14665e+04, 2.57596e+04, 3.00527e+04, 3.43458e+04, 3.86389e+04,
#         4.29320e+04]),
#  <a list of 10 Patch objects>)

# %%
plt.scatter(x,y)

# %%
plt.polar(x,y)

# %%
plt.fill_between(x,y)

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 80212 artists>

# %%
df.plot.area()

# %%
z=df.fg_wac
plt.pie(z)
plt.show()

# %%
sns.heatmap(df.corr())

# %%
sns.countplot(df['Year'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
